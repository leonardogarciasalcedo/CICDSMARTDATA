# %% [markdown]
# **Grants**

# %%
# %sql
GRANT SELECT ON TABLE dev.bronze.cust_detail TO `leonardogarciasalcedo@gmail.com`;

# %%
# %sql
GRANT SELECT ON TABLE dev.bronze.department TO `leonardogarciasalcedo@gmail.com`;

# %%
# %sql
GRANT SELECT ON TABLE dev.bronze.orderq TO `leonardogarciasalcedo@gmail.com`;

# %%
# %sql
GRANT SELECT ON TABLE dev.bronze.orders TO `leonardogarciasalcedo@gmail.com`;

# %%
# %sql
GRANT SELECT ON TABLE dev.bronze.product TO `leonardogarciasalcedo@gmail.com`;

# %%
# %sql
GRANT SELECT ON TABLE dev.bronze.product_place TO `leonardogarciasalcedo@gmail.com`;

# %%
# %sql
GRANT USE CATALOG ON CATALOG dev TO `leonardogarciasalcedo@gmail.com`;

# %%
# %sql
GRANT USE SCHEMA ON SCHEMA dev.bronze TO `developement`;
GRANT CREATE ON SCHEMA dev.bronze TO `developement`;

# %%
# %sql
GRANT SELECT ON TABLE dev.silver.cust_detail TO `Admin`;
GRANT SELECT ON TABLE dev.silver.department TO `Admin`;
GRANT SELECT ON TABLE dev.silver.orderq TO `Admin`;
GRANT SELECT ON TABLE dev.silver.orders TO `Admin`;
GRANT SELECT ON TABLE dev.silver.product TO `Admin`;
GRANT SELECT ON TABLE dev.silver.product_place TO `Admin`;

# %%
# %sql
GRANT SELECT ON TABLE dev.gold.product_cust_deliver TO `archi`;

# %%
# %sql
SHOW GRANTS ON TABLE dev.gold.product_cust_deliver

# %%
# %sql
SHOW GRANTS ON TABLE dev.bronze.cust_detail

# %%
# %sql
SHOW GRANTS ON SCHEMA dev.bronze;

# %%
# %sql
SHOW GRANTS ON SCHEMA dev.silver;

# %%
# %sql
SHOW GRANTS ON SCHEMA dev.gold;

# %%
# %sql
SHOW GRANTS ON CATALOG dev;
