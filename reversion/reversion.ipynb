# %% [markdown]
# ### **Drop Bronze**

# %%
# %sql
DROP TABLE IF EXISTS dev.bronze.cust_detail;
DROP TABLE IF EXISTS dev.bronze.orders;
DROP TABLE IF EXISTS dev.bronze.orderq;
DROP TABLE IF EXISTS dev.bronze.product;
DROP TABLE IF EXISTS dev.bronze.product_desc;
DROP TABLE IF EXISTS dev.bronze.product_place;
DROP TABLE IF EXISTS dev.bronze.department;

# %% [markdown]
# ### **Drop Silver**

# %%
# %sql
DROP TABLE IF EXISTS dev.silver.cust_detail;
DROP TABLE IF EXISTS dev.silver.orders;
DROP TABLE IF EXISTS dev.silver.orderq;
DROP TABLE IF EXISTS dev.silver.product;
DROP TABLE IF EXISTS dev.silver.product_desc;
DROP TABLE IF EXISTS dev.silver.product_place;
DROP TABLE IF EXISTS dev.silver.department;

# %% [markdown]
# ### **Drop Gold**

# %%
# %sql
DROP TABLE IF EXISTS dev.gold.product_cust_deliver;

# %% [markdown]
# **### Remove data files from delta**

# %%
# %python
dbutils.fs.rm(f"abfss://bronze@{storageName}.dfs.core.windows.net/",recurse=True)
dbutils.fs.rm(f"abfss://silver@{storageName}.dfs.core.windows.net/", recurse=True)
dbutils.fs.rm(f"abfss://gold@{storageName}.dfs.core.windows.net/", recurse=True)

# %% [markdown]
# ### **Remove Schemas**

# %% [markdown]
# DROP SCHEMA IF EXISTS dev.bronze;
# DROP SCHEMA IF  EXISTS dev.silver;
# DROP SCHEMA IF  EXISTS dev.gold;
